# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('passengers.csv')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['PassengerId'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: PassengerId, Length: 418, dtype: bool

# %%
df[df['PassengerId'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Pclass'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Sex'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Age'].isna()]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df['Age'].fillna(df['Age'].mean(), inplace = True)

# %%
df[df['Age'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['SibSp'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Parch'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Ticket'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df['Fare'].isna()]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked
# 152   NaN   NaN        S

# %%
# If you don't use subset, it will drop any row with no values.
df.dropna(subset = ['Fare'], inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
df.iloc[152]
# Out:
# PassengerId                                              1045
# Pclass                                                      3
# Name           Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)
# Sex                                                    female
# Age                                                      36.0
# SibSp                                                       0
# Parch                                                       2
# Ticket                                                 350405
# Fare                                                  12.1833
# Cabin                                                     NaN
# Embarked                                                    S
# Name: 153, dtype: object

# %%
df.iloc[150:155]
# Out:
#      PassengerId  Pclass                                            Name  \
# 150         1042       1           Earnshaw, Mrs. Boulton (Olive Potter)
# 151         1043       3                            Matinoff, Mr. Nicola
# 153         1045       3  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)
# 154         1046       3                    Asplund, Master. Filip Oscar
# 155         1047       3                            Duquemin, Mr. Joseph
#
#         Sex       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 150  female  23.00000      0      1          11767  83.1583   C54        C
# 151    male  30.27259      0      0         349255   7.8958   NaN        C
# 153  female  36.00000      0      2         350405  12.1833   NaN        S
# 154    male  13.00000      4      2         347077  31.3875   NaN        S
# 155    male  24.00000      0      0  S.O./P.P. 752   7.5500   NaN        S

# %%
# This drops the old index, so it doesn't create a new column.
df.reset_index(drop = True, inplace = True)

# %%
df.iloc[150:155]
# Out:
#      PassengerId  Pclass                                            Name  \
# 150         1042       1           Earnshaw, Mrs. Boulton (Olive Potter)
# 151         1043       3                            Matinoff, Mr. Nicola
# 152         1045       3  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)
# 153         1046       3                    Asplund, Master. Filip Oscar
# 154         1047       3                            Duquemin, Mr. Joseph
#
#         Sex       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 150  female  23.00000      0      1          11767  83.1583   C54        C
# 151    male  30.27259      0      0         349255   7.8958   NaN        C
# 152  female  36.00000      0      2         350405  12.1833   NaN        S
# 153    male  13.00000      4      2         347077  31.3875   NaN        S
# 154    male  24.00000      0      0  S.O./P.P. 752   7.5500   NaN        S

# %%
df[df['Cabin'].isna()]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 411         1304       3                Henriksson, Miss. Jenny Lovisa
# 412         1305       3                            Spector, Mr. Woolf
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket     Fare Cabin  \
# ...

# %%
df.drop('Cabin', axis = 1, inplace = True)

# %%
df[df['Embarked'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1305       3                            Spector, Mr. Woolf
# 413         1306       1                  Oliva y Ocana, Dona. Fermina
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
df['Embarked'].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
# This converts one column to multiple columns.
pd.get_dummies(df['Embarked'], prefix = 'Embarked')
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           1           0
# 1             0           0           1
# 2             0           1           0
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 412           0           0           1
# 413           1           0           0
# 414           0           0           1
# 415           0           0           1
# 416           1           0           0
#
# [417 rows x 3 columns]

# %%
ohe = pd.get_dummies(df['Embarked'], prefix = 'Embarked')

# %%
ohe
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           1           0
# 1             0           0           1
# 2             0           1           0
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 412           0           0           1
# 413           1           0           0
# 414           0           0           1
# 415           0           0           1
# 416           1           0           0
#
# [417 rows x 3 columns]

# %%
df_ohe = pd.concat([df, ohe], axis = 1)

# %%
df_ohe
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1305       3                            Spector, Mr. Woolf
# 413         1306       1                  Oliva y Ocana, Dona. Fermina
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
df_ohe.drop('Embarked', axis = 1, inplace = True)

# %%
df_ohe
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1305       3                            Spector, Mr. Woolf
# 413         1306       1                  Oliva y Ocana, Dona. Fermina
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare  Embarked_C  \
# ...

# %%
df.groupby(by = 'Sex').count()
# Out:
#         PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Embarked
# Sex
# female          152     152   152  152    152    152     152   152       152
# male            265     265   265  265    265    265     265   265       265

# %%
df.groupby(by = 'Sex').mean()[['Age', 'Fare']]
# Out:
#               Age       Fare
# Sex
# female  30.272400  49.747699
# male    30.158634  27.527877

# %%
# This is similar to "stats" in Elasticsearch.
df.groupby(by = 'Sex').describe()[['Age', 'Fare']]
# Out:
#           Age                                                           Fare  \
#         count       mean        std   min   25%       50%   75%   max  count
# Sex
# female  152.0  30.272400  14.093657  0.17  22.0  30.00000  36.0  76.0  152.0
# male    265.0  30.158634  11.621537  0.33  24.0  30.27259  34.0  67.0  265.0
#
#
#              mean        std   min      25%      50%      75%       max
# Sex
# female  49.747699  73.108716  6.95  8.62605  21.5125  55.4417  512.3292
# male    27.527877  41.079423  0.00  7.85420  13.0000  26.5500  262.3750

# %%
df_1 = df_ohe[['PassengerId', 'Embarked_C', 'Embarked_Q', 'Embarked_S']]

# %%
df_2 = df_ohe[['PassengerId', 'Name', 'Sex', 'Age']]

# %%
df_1
# Out:
#      PassengerId  Embarked_C  Embarked_Q  Embarked_S
# 0            892           0           1           0
# 1            893           0           0           1
# 2            894           0           1           0
# 3            895           0           0           1
# 4            896           0           0           1
# ..           ...         ...         ...         ...
# 412         1305           0           0           1
# 413         1306           1           0           0
# 414         1307           0           0           1
# 415         1308           0           0           1
# 416         1309           1           0           0
#
# [417 rows x 4 columns]

# %%
df_2
# Out:
#      PassengerId                                          Name     Sex  \
# 0            892                              Kelly, Mr. James    male
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female
# 2            894                     Myles, Mr. Thomas Francis    male
# 3            895                              Wirz, Mr. Albert    male
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..           ...                                           ...     ...
# 412         1305                            Spector, Mr. Woolf    male
# 413         1306                  Oliva y Ocana, Dona. Fermina  female
# 414         1307                  Saether, Mr. Simon Sivertsen    male
# 415         1308                           Ware, Mr. Frederick    male
# 416         1309                      Peter, Master. Michael J    male
#
#           Age
# 0    34.50000
# 1    47.00000
# 2    62.00000
# 3    27.00000
# 4    22.00000
# ..        ...
# ...

# %%
pd.merge(df_1, df_2, how = 'inner', on = 'PassengerId')
# Out:
#      PassengerId  Embarked_C  Embarked_Q  Embarked_S  \
# 0            892           0           1           0
# 1            893           0           0           1
# 2            894           0           1           0
# 3            895           0           0           1
# 4            896           0           0           1
# ..           ...         ...         ...         ...
# 412         1305           0           0           1
# 413         1306           1           0           0
# 414         1307           0           0           1
# 415         1308           0           0           1
# 416         1309           1           0           0
#
#                                              Name     Sex       Age
# 0                                Kelly, Mr. James    male  34.50000
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000
# 2                       Myles, Mr. Thomas Francis    male  62.00000
# ...

# %%
df['Age'].hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
df[['Age', 'Fare']].plot.area(alpha = 0.5, figsize = (15, 5))
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x = 'PassengerId', y = 'Age', c = 'Pclass',
                cmap = 'coolwarm', s = df['Pclass'] * 50,
                figsize = (15, 5))
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Age'>

# %%
df_t = pd.DataFrame(data = np.random.randn(30, 2),
                    index = pd.date_range('2020-01-01', '2020-01-30'),
                    columns = ['A', 'B'])

# %%
df_t
# Out:
#                    A         B
# 2020-01-01 -0.502671  0.501081
# 2020-01-02 -0.136161 -0.172382
# 2020-01-03 -0.472835 -0.825790
# 2020-01-04  0.192995 -0.733552
# 2020-01-05 -1.046823 -0.330747
# 2020-01-06 -0.432678  1.733254
# 2020-01-07 -1.121883 -0.817600
# 2020-01-08  0.532364  0.521291
# 2020-01-09 -0.174616 -0.309389
# 2020-01-10 -0.079495  0.618858
# 2020-01-11 -1.409263 -0.393009
# 2020-01-12 -0.478453 -0.182260
# 2020-01-13  0.011675  0.489259
# 2020-01-14  0.645110  1.768514
# 2020-01-15 -0.328468  0.582819
# 2020-01-16  1.170924  0.257456
# 2020-01-17 -0.770072  1.210216
# 2020-01-18  1.771915  0.490107
# 2020-01-19 -1.816527 -1.569900
# 2020-01-20  1.439654  1.750103
# 2020-01-21 -0.199112  0.452653
# 2020-01-22  0.531084  0.876866
# 2020-01-23  0.857642  1.306426
# 2020-01-24  0.268882 -0.230798
# 2020-01-25  0.881387  1.024801
# 2020-01-26  0.559090 -1.761637
# 2020-01-27  1.092153  1.734666
# 2020-01-28 -0.566113  0.315277
# 2020-01-29 -0.013885 -1.978774
# ...

# %%
df_t.plot.bar(stacked = True, figsize = (15, 5))
# Out:
# <AxesSubplot:>

# %%
df_t.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# This one creates distinct charts.
df_t.hist()
# Out:
# array([[<AxesSubplot:title={'center':'A'}>,
#         <AxesSubplot:title={'center':'B'}>]], dtype=object)

# %%
df_t.plot.box()
# Out:
# <AxesSubplot:>
